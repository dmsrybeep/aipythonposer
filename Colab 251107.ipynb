# %%
a = np.array([1,2,3,4,5])

# %%
print(a)
# Out:
# [1 2 3 4 5]

# %%
type(a)
# Out:
# numpy.ndarray

# %%
b=[1,2,3,4,5]

# %%
type(b)
# Out:
# list

# %%
b = np.array([[1, 2, 3], [4, 5, 6]])

# %%
print(np.sum(a))
# Out:
# 15

# %%
print(np.min(a))
# Out:
# 1

# %%
print(np.max(a))
# Out:
# 5

# %%
print(np.mean(a))
# Out:
# 3.0

# %%
a = np.array([11, 8, 2025, 12, 7])

condition_mask = (a > 10)
filtered_array = a[condition_mask]
print(filtered_array)
# Out:
# [  11 2025   12]

# %%
import numpy as np

# %%
distances=np.array([1,2,3,5,8])

# %%
windspeeds=np.array([0,5,10,7,12])

# %%
base_usage_rate = 10

# %%
additional_usage_rate = windspeeds

# %%
total_usage_rate = base_usage_rate + additional_usage_rate

# %%
battery_consumption = distances * total_usage_rate

# %%
print("비행 거리 (km):", distances)
print("풍속 (m/s):", windspeeds)
print("총 소모율 (%/km):", total_usage_rate)
print("예상 배터리 소모량 (%):", battery_consumption)
# Out:
# 비행 거리 (km): [1 2 3 5 8]
# 풍속 (m/s): [ 0  5 10  7 12]
# 총 소모율 (%/km): [10 15 20 17 22]
# 예상 배터리 소모량 (%): [ 10  30  60  85 176]

# %%
df = pd.read_csv('Iris.csv')
display(df.head(10))
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
df = pd.read_csv('Iris.csv')
print(df.tail(10))
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# ...

# %%
# 'SepalLengthCm' 컬럼 값이 5 미만인 조건을 만듭니다.
condition = df['SepalLengthCm'] < 5

# 조건을 사용하여 데이터프레임을 필터링합니다.
df_sepal_length_less_than_5 = df[condition]

# 필터링된 데이터프레임의 처음 5행을 출력하여 확인합니다.
print("SepalLengthCm이 5 미만인 데이터:")
display(df_sepal_length_less_than_5.head())

# 필터링된 데이터프레임의 총 행 수를 확인합니다.
print(f"\n총 {len(df_sepal_length_less_than_5)}개의 행이 조건을 만족합니다.")
# Out:
# SepalLengthCm이 5 미만인 데이터:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 총 22개의 행이 조건을 만족합니다.
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16['Id'].plot(kind='hist', bins=20, title='Id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['SepalLengthCm'].plot(kind='hist', bins=20, title='SepalLengthCm')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...
